# %%
from empyrial import empyrial, Engine

portfolio = Engine(
      start_date = "2018-01-01",
      benchmark = ["SPY"], #SPY is set by default
      portfolio = ["BTC", "ETH", "XRP", "LTC", "BCH", "EOS", "XLM", "ADA", "TRX", "MIOTA"],
      optimizer = "EF"
)

empyrial(portfolio)
# Out:
# 4 Failed downloads:
# - ETH: No data found, symbol may be delisted
# - XLM: No data found for this date range, symbol may be delisted
# - MIOTA: No data found, symbol may be delisted
# - XRP: No data found for this date range, symbol may be delisted
#
# 4 Failed downloads:
# - ETH: No data found, symbol may be delisted
# - XLM: No data found for this date range, symbol may be delisted
# - MIOTA: No data found, symbol may be delisted
# - XRP: No data found for this date range, symbol may be delisted
# Start date: 2018-01-01
# End date: 2022-10-02
#                     Backtest
#
# Annual return          7.17%
# Cumulative return     38.86%
# Annual volatility    24.44 %
# Winning day ratio     54.81%
# Sharpe ratio            0.41
# Calmar ratio            0.17
# Information ratio       -0.0
# Stability               0.72
# Max Drawdown         -41.1 %
# Sortino ratio           0.55
# Skew                   -0.68
# Kurtosis               15.77
# Tail Ratio              0.92
# Common sense ratio       1.0
# Daily value at risk   -2.0 %
# Alpha                    0.0
# Beta                    0.96
# (None, None, None, None, None, None, None, None, None)

# %%
from empyrial import get_report, Engine

portfolio = Engine(
      start_date = "2018-01-01",
      portfolio = ["BLK", "BAC", "AAPL", "TM", "JPM","JD", "INTU", "NVDA", "DIS", "TSLA"],
      optimizer = "EF",
      rebalance = "1y", 
      risk_manager = {"Stop Loss" : -0.2}
)

get_report(portfolio)
